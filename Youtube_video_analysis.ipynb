# %%
import requests

# %%
video_id="Q38f4frs8yc"
api_key="AIzaSyCQA7OrXCTxkwSS40ZBR1-yFHsLkdZtqnk"

# %%
video_info_url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet&id={video_id}&key={api_key}"
video_info_response=requests.get(video_info_url)
video_info_data = video_info_response.json()

# %%
video_info_data
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'PN2X9QT6eJQM-L3vQp7hqQNTgKk',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'gjszj3zAR1sk5V6KDNtg8Ava8Tc',
#    'id': 'Q38f4frs8yc',
#    'snippet': {'publishedAt': '2022-01-03T11:30:14Z',
#     'channelId': 'UCUom-mQVeYZiaxYq6uWhqZw',
#     'title': 'Tum Tum - Video Song (Hindi) | Enemy | Vishal | Arya | Anand Shankar | Vinod Kumar | Thaman S',
#     'description': 'Miss attending weddings? Don\'t worry we have an amazing song \'Tum Tum\' (Hindi) from Enemy that you can dance to. Get ready to groove 💃\n\nStarring – Vishal, Arya, Prakash Raj, Thambi Ramaiah, Karunakaran, Mamta Mohandas, Mirnalini Ravi\n\nSong Credits:\n\nSong - Tum Tum (Hindi)\nSingers - Vidhya Gopal, Yashika Sikka, Darshana Menon, Reena Gilbert, Aishwarya Kumar\nLyrics - Snehalata Chari and Rev Shergill.\nComposed Programmed and Arranged by Thaman S\n\nListen to "Tum Tum (From "Enemy - Hindi")" Song on your favorite streaming platforms :- \n\nApple Music - https://apple.co/3HwH8SA\niTunes - https://apple.co/3HwH8SA\nAmazon Music  - https://amzn.to/3sQW75z\nYoutube Music - https://bit.ly/3mQyMgE\nWynk  - https://bit.ly/3qGe7wR\nRaaga: https://www.raaga.com/hindi/movie/enemy-songs-H004966-play\n\nCast and Crew:\n\nWritten And Directed by Anand Shankar\nProduced by S Vinod Kumar\nAssociate Producers – Sunil Shah , Raja Subramanian\nSong Composed by – Thaman S \nBackground Score Composed By – Sam CS\nDOP– RD Rajasekar ISC\nDialogues – Shan Karuppusamy\nScreenplay – Anand Shankar , Shan Karuppusamy , S Ramakrishnan\nProduction Designer – T Ramalingam\nEditor – Raymond Derrick Crasta\nDance Directors – Brindha , Sathish Krishnan\nAction Director – Ravi Verma\nSound Designer – A S Lakshminarayanan\nCostume Designer - Pritha Agarwal\nExecutive Producer – S P Chockalingam\nFirst AD – Mukundan  \nSecond AD - Praveen\nPublicity Design – Gopi Prasannaa\nStill Photographer – D Narendran\nPro – Riaz K Ahmed, Team BA Raju\nVFX - Futureworks Media Ltd\nColorist -KS Rajasekaran (Knack Studios)\nDigital And Music Partner – Divo\n\nMusician Credits:\n\nVocal Supervision - Soumya Sejpal\nAdditional Programming - Osho V \nSolo Violin - Sandiliya\nGuitar - Shubashree Jk\nIndie Strings - Subhan\nSong Recorded @ Euphony Studio Mumbai, AMV Studio Mumbai and KMMC Studio Chennai\nMusicians Co Ordinator - Soumya Sejpal\nAssisted By - Pukraj\nRecording Engineers - Partha Protim Das, Vinayak Pawar, Sam\nStudio Manager - Seenu\nStudio Assistance - Kannan,Lingam,Raju & Ranjith\n\nSubscribe to divomusic : http://bit.ly/divomusic\n\nIn Association with Divo\nFB : https://www.facebook.com/divomovies/\nTwitter : https://www.twitter.com/divomovies/\nInsta : https://www.instagram.com/divomovies/\nTelegram : https://t.me/divodigital\n\n#TumTum #Enemy #Vishal',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Q38f4frs8yc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Q38f4frs8yc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Q38f4frs8yc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Q38f4frs8yc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Q38f4frs8yc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Divo Music Hindi',
#     'tags': ['tum tum video',
#      'tum tum enemy song',
#      'tum tum thaman song',
#      'tum tum',
#      'enemy movie song',
#      'enemy movie',
#      'tum tum vishal song',
#      'tum tum mrunalini',
#      'Mrinalini ravi',
#      'mirnalini ravi dance',
#      'mirnalini ravi movie',
#      'enemy vishal arya',
#      'vishal enemy',
#      'enemy vishal and arya',
#      'enemy vishal',
#      'enemy vishal arya movie',
#      'enemy vishal and arya movie',
#      'enemy arya and vishal',
#      'enemy vishal movie',
#      'vishal & arya in enemy',
#      'enemy arya movie',
#      'Anand Shankar',
#      'thaman music director',
#      'divo',
#      'enemy',
#      'tum tum hindi video'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'Tum Tum - Video Song (Hindi) | Enemy | Vishal | Arya | Anand Shankar | Vinod Kumar | Thaman S',
#      'description': 'Miss attending weddings? Don\'t worry we have an amazing song \'Tum Tum\' (Hindi) from Enemy that you can dance to. Get ready to groove 💃\n\nStarring – Vishal, Arya, Prakash Raj, Thambi Ramaiah, Karunakaran, Mamta Mohandas, Mirnalini Ravi\n\nSong Credits:\n\nSong - Tum Tum (Hindi)\nSingers - Vidhya Gopal, Yashika Sikka, Darshana Menon, Reena Gilbert, Aishwarya Kumar\nLyrics - Snehalata Chari and Rev Shergill.\nComposed Programmed and Arranged by Thaman S\n\nListen to "Tum Tum (From "Enemy - Hindi")" Song on your favorite streaming platforms :- \n\nApple Music - https://apple.co/3HwH8SA\niTunes - https://apple.co/3HwH8SA\nAmazon Music  - https://amzn.to/3sQW75z\nYoutube Music - https://bit.ly/3mQyMgE\nWynk  - https://bit.ly/3qGe7wR\nRaaga: https://www.raaga.com/hindi/movie/enemy-songs-H004966-play\n\nCast and Crew:\n\nWritten And Directed by Anand Shankar\nProduced by S Vinod Kumar\nAssociate Producers – Sunil Shah , Raja Subramanian\nSong Composed by – Thaman S \nBackground Score Composed By – Sam CS\nDOP– RD Rajasekar ISC\nDialogues – Shan Karuppusamy\nScreenplay – Anand Shankar , Shan Karuppusamy , S Ramakrishnan\nProduction Designer – T Ramalingam\nEditor – Raymond Derrick Crasta\nDance Directors – Brindha , Sathish Krishnan\nAction Director – Ravi Verma\nSound Designer – A S Lakshminarayanan\nCostume Designer - Pritha Agarwal\nExecutive Producer – S P Chockalingam\nFirst AD – Mukundan  \nSecond AD - Praveen\nPublicity Design – Gopi Prasannaa\nStill Photographer – D Narendran\nPro – Riaz K Ahmed, Team BA Raju\nVFX - Futureworks Media Ltd\nColorist -KS Rajasekaran (Knack Studios)\nDigital And Music Partner – Divo\n\nMusician Credits:\n\nVocal Supervision - Soumya Sejpal\nAdditional Programming - Osho V \nSolo Violin - Sandiliya\nGuitar - Shubashree Jk\nIndie Strings - Subhan\nSong Recorded @ Euphony Studio Mumbai, AMV Studio Mumbai and KMMC Studio Chennai\nMusicians Co Ordinator - Soumya Sejpal\nAssisted By - Pukraj\nRecording Engineers - Partha Protim Das, Vinayak Pawar, Sam\nStudio Manager - Seenu\nStudio Assistance - Kannan,Lingam,Raju & Ranjith\n\nSubscribe to divomusic : http://bit.ly/divomusic\n\nIn Association with Divo\nFB : https://www.facebook.com/divomovies/\nTwitter : https://www.twitter.com/divomovies/\nInsta : https://www.instagram.com/divomovies/\nTelegram : https://t.me/divodigital\n\n#TumTum #Enemy #Vishal'},
#     'defaultAudioLanguage': 'hi'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
comments_url = f"https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={video_id}&key={api_key}"
comment_response = requests.get(comments_url)
comment_data = comment_response.json()

# %%
comment_data
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'NoFAvLBJt20WBOsXsIQJPIo_15o',
#  'nextPageToken': 'QURTSl9pMEtsSlBjWVRmaWJaM0ZRNDJSclk2V1NBcHV1c1JfQ19TejFpRHhLM3VoX0dkSHh2WUlJYW1vbEs2eVVlUmhjaGdnTHQ2Z2l1cw==',
#  'pageInfo': {'totalResults': 19, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'vTLlSBYHow2u6aevxcl3F7Ki1Bo',
#    'id': 'Ugy2vwSJ3TG_Wt7OWRx4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'LaGKwy0satCqIBoMS86_lsk8Bwo',
#      'id': 'Ugy2vwSJ3TG_Wt7OWRx4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Movie name',
#       'textOriginal': 'Movie name',
#       'authorDisplayName': 'Hasan Zamil',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/jxOb--7YbyXqXKa3yLI9HLCSBZOhg3jSeuP1zOctbX76Aoga-IBLk2Aoy4vmETAOG_9uUz2b7g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCTIDRUsaxvYUFxwaVP8G-eA',
#       'authorChannelId': {'value': 'UCTIDRUsaxvYUFxwaVP8G-eA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T10:36:34Z',
#       'updatedAt': '2023-04-26T10:36:34Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '_900OEBbvjnxurr2Fyz7mhsDicI',
#    'id': 'Ugw_Ub13_l4pM6W1uxd4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'DOxwn1o4O8brlMhYar67gcdWyLc',
#      'id': 'Ugw_Ub13_l4pM6W1uxd4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Love this song 🎵 ❤️',
#       'textOriginal': 'Love this song 🎵 ❤️',
#       'authorDisplayName': 'Arsh Arya',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqPglvT0EqLhgZjyV1ZYxris7BzyBkR7C8B-23hySQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC4WMi40oH04YyeZpDAho4Pg',
#       'authorChannelId': {'value': 'UC4WMi40oH04YyeZpDAho4Pg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T10:24:17Z',
#       'updatedAt': '2023-04-26T10:24:17Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Acuqpr3rTQLw4PRLoZz_1cgdFGc',
#    'id': 'Ugy9MoPPWDgfIZ7i4od4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'wf2qVdkLsH0zSuE7IdMrYi4Gu-4',
#      'id': 'Ugy9MoPPWDgfIZ7i4od4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Dish song Tamil is so good 😊😊',
#       'textOriginal': 'Dish song Tamil is so good 😊😊',
#       'authorDisplayName': 'Total_Games_Simulator',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/RnMRhzoRL_jfrTpaSLnA-qUwN6y_qAKLiOJS6BJTPb5ReemLmcIo4q7eWq7SlohArBtwEYLSqCY=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCncWCuBAxIRo0UFsUvDJTGg',
#       'authorChannelId': {'value': 'UCncWCuBAxIRo0UFsUvDJTGg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T10:11:14Z',
#       'updatedAt': '2023-04-26T10:11:14Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'rWX43Nfh2RVXE5okJu6YBNTPD3A',
#    'id': 'Ugx2QuTzMeKXc5gjWGJ4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4vdEwRylta91kFrX5eH0OW2IeFA',
#      'id': 'Ugx2QuTzMeKXc5gjWGJ4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Hindi version is best but original is original... ❤Good Job😊',
#       'textOriginal': 'Hindi version is best but original is original... ❤Good Job😊',
#       'authorDisplayName': 'Poonam Salvi',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqMOB6ou1rviYVL6lEhkAvf2CvrSDYSYqseLKsFF5Xs=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCbB03F_U5QLG8pRiudixvHw',
#       'authorChannelId': {'value': 'UCbB03F_U5QLG8pRiudixvHw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T09:34:21Z',
#       'updatedAt': '2023-04-26T09:34:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'UMIa7iWjKo83rNIaK7_WfVAI0G8',
#    'id': 'Ugz9OJLdrg3Ffin5Alp4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'wv2KReEZkeO0fKB2kdfPV9_LXbs',
#      'id': 'Ugz9OJLdrg3Ffin5Alp4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': '🙏🏻 Please help🙏🏻<br>💥💥💥HI🌷 am a youtuber 💥💥💥<br><br>,💥💥💥,🌷मैं एक् यूट्यूब  हूँ💥💥💥<br>💥💥💥🌷 i create a youtube channel🌷💥💥💥<br>💥💥💥🌷मेने एक यूट्यूब चैनल बनाया हैं💥💥💥',
#       'textOriginal': '🙏🏻 Please help🙏🏻\n💥💥💥HI🌷 am a youtuber 💥💥💥\n\n,💥💥💥,🌷मैं एक् यूट्यूब  हूँ💥💥💥\n💥💥💥🌷 i create a youtube channel🌷💥💥💥\n💥💥💥🌷मेने एक यूट्यूब चैनल बनाया हैं💥💥💥',
#       'authorDisplayName': '#sad hitz',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/zdalTo87SV4B0RMlb_dF2qnmwYjdzANSiZYaLWqdxCk_vQrcgICWdyuOO8irP7c-GO7g2-WACA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCKzKifdDze7UJuTGEt7Ce6Q',
#       'authorChannelId': {'value': 'UCKzKifdDze7UJuTGEt7Ce6Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T06:30:38Z',
#       'updatedAt': '2023-04-26T06:30:38Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nSuyW_f6lNOeDkQkpvWN8nGZ2SY',
#    'id': 'UgwCL5JDya6MiINJxtF4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'O7MgLR-NA6-07P_edZPJ0RHF224',
#      'id': 'UgwCL5JDya6MiINJxtF4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': '💥💥💥HI🌷 am a youtuber 💥💥💥<br><br>,💥💥💥,🌷मैं एक् यूट्यूब  हूँ💥💥💥<br>💥💥💥🌷 i create a youtube channel🌷💥💥💥<br>💥💥💥🌷मेने एक यूट्यूब चैनल बनाया हैं💥💥💥',
#       'textOriginal': '💥💥💥HI🌷 am a youtuber 💥💥💥\n\n,💥💥💥,🌷मैं एक् यूट्यूब  हूँ💥💥💥\n💥💥💥🌷 i create a youtube channel🌷💥💥💥\n💥💥💥🌷मेने एक यूट्यूब चैनल बनाया हैं💥💥💥',
#       'authorDisplayName': '#sad hitz',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/zdalTo87SV4B0RMlb_dF2qnmwYjdzANSiZYaLWqdxCk_vQrcgICWdyuOO8irP7c-GO7g2-WACA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCKzKifdDze7UJuTGEt7Ce6Q',
#       'authorChannelId': {'value': 'UCKzKifdDze7UJuTGEt7Ce6Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T06:29:09Z',
#       'updatedAt': '2023-04-26T06:29:09Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '1KkZx-8BsUzrfjy3wagkyaDOW5U',
#    'id': 'Ugxe8GWY6K2ym5dGKF94AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Zzr9YOA6ViHO-j0azhMjz88VaH4',
#      'id': 'Ugxe8GWY6K2ym5dGKF94AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Finally no we can Bueb with every single word<br>But still original has more bass',
#       'textOriginal': 'Finally no we can Bueb with every single word\nBut still original has more bass',
#       'authorDisplayName': 'Haris Mehmood',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOnaggKztYIb8pRIaTwQsORM43kKw1TCgv19VEqnxcWR1qf10EsLhVcNFkwtXv0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCt3SQWlrxtUU5pS7kyDV-0w',
#       'authorChannelId': {'value': 'UCt3SQWlrxtUU5pS7kyDV-0w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T06:23:04Z',
#       'updatedAt': '2023-04-26T06:23:18Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'uhUNYwTjCqAIatWOR25yJx6sMx0',
#    'id': 'UgyLVvLne1-bnTX26_94AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Z4g3gPexXqWSaSaJPzB4QvmrK-s',
#      'id': 'UgyLVvLne1-bnTX26_94AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Hii',
#       'textOriginal': 'Hii',
#       'authorDisplayName': 'purulia status video',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/PdDrQUZ5142Rd4M_9ENGDH9GfAQKEWp2ywSVZlChjzMa4uqo7FhKGGOsccdZhcMYrgR7lwvyXq4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC-ETIXTAl7TOmgLcyFK8ZDg',
#       'authorChannelId': {'value': 'UC-ETIXTAl7TOmgLcyFK8ZDg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T05:52:46Z',
#       'updatedAt': '2023-04-26T05:52:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'hJGsLFz_qOGrbFvu_NOjkWMcYRk',
#    'id': 'UgwIT_eU4-eXJ3PpUGN4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'eqZn5flgQIG1gj4Ill07B2LIvHI',
#      'id': 'UgwIT_eU4-eXJ3PpUGN4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Nice',
#       'textOriginal': 'Nice',
#       'authorDisplayName': 'purulia status video',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/PdDrQUZ5142Rd4M_9ENGDH9GfAQKEWp2ywSVZlChjzMa4uqo7FhKGGOsccdZhcMYrgR7lwvyXq4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC-ETIXTAl7TOmgLcyFK8ZDg',
#       'authorChannelId': {'value': 'UC-ETIXTAl7TOmgLcyFK8ZDg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T05:52:40Z',
#       'updatedAt': '2023-04-26T05:52:40Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'L0ULNXaer5OseKwP4O4v52ROboM',
#    'id': 'UgxUW90Sp_JiQV3bKYB4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mnj49cqh8MtfGOaHKhruD1IVqos',
#      'id': 'UgxUW90Sp_JiQV3bKYB4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Love',
#       'textOriginal': 'Love',
#       'authorDisplayName': 'purulia status video',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/PdDrQUZ5142Rd4M_9ENGDH9GfAQKEWp2ywSVZlChjzMa4uqo7FhKGGOsccdZhcMYrgR7lwvyXq4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC-ETIXTAl7TOmgLcyFK8ZDg',
#       'authorChannelId': {'value': 'UC-ETIXTAl7TOmgLcyFK8ZDg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T05:52:36Z',
#       'updatedAt': '2023-04-26T05:52:36Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'WL8KE02NIdC8HEtUEZdCORSYllg',
#    'id': 'UgwEXmi8Gw9MW27NyZh4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'k2_CYUeGX3RsgF_dOf6x53i4P84',
#      'id': 'UgwEXmi8Gw9MW27NyZh4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Nice Op music 🎶🎶🎶🎶🎶',
#       'textOriginal': 'Nice Op music 🎶🎶🎶🎶🎶',
#       'authorDisplayName': 'purulia status video',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/PdDrQUZ5142Rd4M_9ENGDH9GfAQKEWp2ywSVZlChjzMa4uqo7FhKGGOsccdZhcMYrgR7lwvyXq4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC-ETIXTAl7TOmgLcyFK8ZDg',
#       'authorChannelId': {'value': 'UC-ETIXTAl7TOmgLcyFK8ZDg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T05:52:31Z',
#       'updatedAt': '2023-04-26T05:52:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'uC5XyAeWKI6yVUz8JMQ3opsjmF0',
#    'id': 'UgzZOmQIbeF-4XuX5tp4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'JOSHPKx4Gun7AqKbS_19rUDryp8',
#      'id': 'UgzZOmQIbeF-4XuX5tp4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Super❤❤',
#       'textOriginal': 'Super❤❤',
#       'authorDisplayName': 'Prem Bashyal',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-9emITtW-uTWLHqOtDKYlWnIFRHsHiBaRoOZP5URrC4m9f3fnqyHtii0_PChu6-CPf_RHTJ6oA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC8HeW2PYnvFIC5KOt2CxprQ',
#       'authorChannelId': {'value': 'UC8HeW2PYnvFIC5KOt2CxprQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T04:23:59Z',
#       'updatedAt': '2023-04-26T04:23:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '96LuCpwFGbONh8eMYAkXJhUPBnc',
#    'id': 'UgzZqNRiYnwk_tpOGtF4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'eBn6APNGAdMj5rSFr8j9BWt1bdo',
#      'id': 'UgzZqNRiYnwk_tpOGtF4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Kiska man is song ko sune ke bad Pura tum tum ho gaya',
#       'textOriginal': 'Kiska man is song ko sune ke bad Pura tum tum ho gaya',
#       'authorDisplayName': 'Sakshampandeychs',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/lPJTw0oJYGNlrEnFQfSDzorI-cAoK9ZOIECgK8CaTWf-vXpMvtW7qoR8JQIUPbTvvLVm-KXXxw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCA12Kh_wQKfh7MoViGToSLw',
#       'authorChannelId': {'value': 'UCA12Kh_wQKfh7MoViGToSLw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T04:09:22Z',
#       'updatedAt': '2023-04-26T04:09:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'O5yrSUoUPRB5s9WYiriH9prLanU',
#    'id': 'Ugw_1Pyelf1XRWxDgKx4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'l9m9KuRnlpAvIITiuWd3HChtixM',
#      'id': 'Ugw_1Pyelf1XRWxDgKx4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'this song is getting popular now',
#       'textOriginal': 'this song is getting popular now',
#       'authorDisplayName': 'Indiacha',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/cDFLYcyUX18mRcpGRYKIrAY9zYtu98go2d0zBmjRvhN3ifygQDK6cyq0y5nEgFT0jYcLWOflopA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC_jr4ILfq-LQA2ejoIfTjwA',
#       'authorChannelId': {'value': 'UC_jr4ILfq-LQA2ejoIfTjwA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T03:48:48Z',
#       'updatedAt': '2023-04-26T03:48:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'bLi9bZPvwCay20gMbAvY6YA-F7A',
#    'id': 'Ugw7odnBSppITD2paf54AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'GEaRq2xqFgMDG5e20yEDDYcQEvg',
#      'id': 'Ugw7odnBSppITD2paf54AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'WOW URDU DUBBED  THANKS SUPREB SONG VIRAL ON TIKTOK',
#       'textOriginal': 'WOW URDU DUBBED  THANKS SUPREB SONG VIRAL ON TIKTOK',
#       'authorDisplayName': 'Freedom Samosa',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Wz2IIBBFq0yS3qNVNJoUj3Q1aIOh8Gn6T0RsY17hiBLc5234ES_37RePARViiIikdXs01yx3VKk=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC8-PFQrBRio9JLF9MjQP4Rw',
#       'authorChannelId': {'value': 'UC8-PFQrBRio9JLF9MjQP4Rw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-26T03:36:10Z',
#       'updatedAt': '2023-04-26T03:36:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'IAMKIHf2GsJHy84nhEbzjGthXM4',
#    'id': 'Ugzg0kIiJAbVdVVAPC14AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'VRUxt-ksgMS_Jw-Ratvp7gDLHHg',
#      'id': 'Ugzg0kIiJAbVdVVAPC14AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'movieo name',
#       'textOriginal': 'movieo name',
#       'authorDisplayName': 'ABDUR RAHMAN',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqNbG4HCc5lz-wLFQg2RzGdK_gybS38Jeefx1HpfPR-U4CazktBz2rmXTNKEM7Mf=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC0H_y9Vs8sYaZ7RpkiftnUg',
#       'authorChannelId': {'value': 'UC0H_y9Vs8sYaZ7RpkiftnUg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-25T16:05:24Z',
#       'updatedAt': '2023-04-25T16:05:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Zfki8mC2ejaakCIMHrNKXjmve3s',
#    'id': 'UgwHYHlU5rp3QeM4ISp4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 't3kW5Mgrgx5iYq5QPWzJlAHhqwk',
#      'id': 'UgwHYHlU5rp3QeM4ISp4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'moveio',
#       'textOriginal': 'moveio',
#       'authorDisplayName': 'ABDUR RAHMAN',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqNbG4HCc5lz-wLFQg2RzGdK_gybS38Jeefx1HpfPR-U4CazktBz2rmXTNKEM7Mf=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC0H_y9Vs8sYaZ7RpkiftnUg',
#       'authorChannelId': {'value': 'UC0H_y9Vs8sYaZ7RpkiftnUg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-25T16:04:46Z',
#       'updatedAt': '2023-04-25T16:04:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'EwHIzSMGSeh0krlJk_Ty4t-j2Xs',
#    'id': 'UgzWRdmkDTNucxto6O14AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4-kDs8MKbuyfoadB_48eUZ_vu4Q',
#      'id': 'UgzWRdmkDTNucxto6O14AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'Nice',
#       'textOriginal': 'Nice',
#       'authorDisplayName': 'Ankit Kashyap Tabla',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/yg7-yftBsQGmWkfzrb9p53N7OUBxtP9tVXy9npTk4uSzz3g2bigL9J6GFMcLUeZLed632yvnaA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC4WJHyokI2kBnN31rF5RKiw',
#       'authorChannelId': {'value': 'UC4WJHyokI2kBnN31rF5RKiw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-25T12:58:03Z',
#       'updatedAt': '2023-04-25T12:58:03Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'M3tmYTCoNVNjlnZt0Uo-C90bLwc',
#    'id': 'Ugwfg63Zn3yRQo7elBR4AaABAg',
#    'snippet': {'videoId': 'Q38f4frs8yc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Awfk5eWIqBsB5sdP0QJ_UmvGcgY',
#      'id': 'Ugwfg63Zn3yRQo7elBR4AaABAg',
#      'snippet': {'videoId': 'Q38f4frs8yc',
#       'textDisplay': 'nice song tum tum',
#       'textOriginal': 'nice song tum tum',
#       'authorDisplayName': 'Nilesh Meshvaniya',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqN7kdVm8-FSx0ELchnOqm4hcsYRovS4yf3Cx3eg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCBcQy9glE5tehhOdGRQI61g',
#       'authorChannelId': {'value': 'UCBcQy9glE5tehhOdGRQI61g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-04-25T12:24:23Z',
#       'updatedAt': '2023-04-25T12:24:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
comments=[item["snippet"]["topLevelComment"]["snippet"]["textOriginal"]for item in comment_data["items"]]
print(comments)
# Out:
# ['Movie name', 'Love this song 🎵 ❤️', 'Dish song Tamil is so good 😊😊', 'Hindi version is best but original is original... ❤Good Job😊', '🙏🏻 Please help🙏🏻\n💥💥💥HI🌷 am a youtuber 💥💥💥\n\n,💥💥💥,🌷मैं एक् यूट्यूब  हूँ💥💥💥\n💥💥💥🌷 i create a youtube channel🌷💥💥💥\n💥💥💥🌷मेने एक यूट्यूब चैनल बनाया हैं💥💥💥', '💥💥💥HI🌷 am a youtuber 💥💥💥\n\n,💥💥💥,🌷मैं एक् यूट्यूब  हूँ💥💥💥\n💥💥💥🌷 i create a youtube channel🌷💥💥💥\n💥💥💥🌷मेने एक यूट्यूब चैनल बनाया हैं💥💥💥', 'Finally no we can Bueb with every single word\nBut still original has more bass', 'Hii', 'Nice', 'Love', 'Nice Op music 🎶🎶🎶🎶🎶', 'Super❤❤', 'Kiska man is song ko sune ke bad Pura tum tum ho gaya', 'this song is getting popular now', 'WOW URDU DUBBED  THANKS SUPREB SONG VIRAL ON TIKTOK', 'movieo name', 'moveio', 'Nice', 'nice song tum tum']

# %%
from textblob import TextBlob

# %%
def get_comment_sentiment(comments):
  analysis = TextBlob(comments)
  if analysis.sentiment.polarity >0 :
    return "positive"
  elif analysis.sentiment.polarity == 0 :
    return "neutral"
  else:
    return "negative"

# %%
comment_list = []
sentiment_list = []
for comment in comments:
  sentiment = get_comment_sentiment(comment)
  comment_list.append(comment)
  sentiment_list.append(sentiment)
  print(f"{comment}:{sentiment}")
# Out:
# Movie name:neutral
# Love this song 🎵 ❤️:positive
# Dish song Tamil is so good 😊😊:positive
# Hindi version is best but original is original... ❤Good Job😊:positive
# 🙏🏻 Please help🙏🏻
# 💥💥💥HI🌷 am a youtuber 💥💥💥
#
# ,💥💥💥,🌷मैं एक् यूट्यूब  हूँ💥💥💥
# 💥💥💥🌷 i create a youtube channel🌷💥💥💥
# 💥💥💥🌷मेने एक यूट्यूब चैनल बनाया हैं💥💥💥:neutral
# 💥💥💥HI🌷 am a youtuber 💥💥💥
#
# ,💥💥💥,🌷मैं एक् यूट्यूब  हूँ💥💥💥
# 💥💥💥🌷 i create a youtube channel🌷💥💥💥
# 💥💥💥🌷मेने एक यूट्यूब चैनल बनाया हैं💥💥💥:neutral
# Finally no we can Bueb with every single word
# But still original has more bass:positive
# Hii:neutral
# Nice:positive
# Love:positive
# Nice Op music 🎶🎶🎶🎶🎶:positive
# Super❤❤:neutral
# Kiska man is song ko sune ke bad Pura tum tum ho gaya:negative
# this song is getting popular now:positive
# WOW URDU DUBBED  THANKS SUPREB SONG VIRAL ON TIKTOK:positive
# movieo name:neutral
# moveio:neutral
# Nice:positive
# nice song tum tum:positive

# %%
import pandas as pd

# %%
sentiment_df = pd.DataFrame({"comments":comment_list,"sentiment":sentiment_list})
sentiment_df.to_csv("Dekhmat.csv")
